# %%
import time, re, datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
MV_list = []

# %%
List_Channel_videos = ['https://www.youtube.com/@ensemble_stars/videos', 'https://www.youtube.com/@happyelementskk/videos']

# %%
chrome_options = Options()
#chrome_options.page_load_strategy = 'headless'
#chrome_options.add_argument('headless')

# %%
def scraping_viewed(channel):

    driver = Service('/Users/shinmanoko/Desktop/chromedriver-mac-x64/chromedriver')
    browser = webdriver.Chrome(service=driver, options=chrome_options)
    browser.get(channel)
    time.sleep(5)

    now = datetime.datetime.now()
    print(now)

    old_height = browser.execute_script("return document.documentElement.scrollHeight;")
    browser.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(5)
    new_height = browser.execute_script("return document.documentElement.scrollHeight;")

    print(new_height == old_height)

    # 模拟浏览器向下滚动页面，直到所有视频都被加载出来
    while new_height != old_height:
        old_height = new_height
        browser.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(15)
        new_height = browser.execute_script("return document.documentElement.scrollHeight;")

        html = browser.page_source
        soup = BeautifulSoup(html, 'html.parser')
        #videoList = soup.find_all("a", {"class": "yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media"})
        videoList = soup.find_all("a", {"id": "video-title-link"})
        #videoList = soup.findAll("a")
        for video in videoList:
            if "あんさんぶるスターズ！！ Music ゲームサイズMV" in video['aria-label']:
                #print(video['aria-label'])
                MV_list.append(video['aria-label'])

# %%
for channel in List_Channel_videos:
    scraping_viewed(channel)
# Out:
# 2023-12-24 03:24:04.613184
# False
# 2023-12-24 03:27:24.820838
# False

# %%
print(len(MV_list))
print(len(set(MV_list)))
# Out:
# 1529
# 257

# %%
import pandas as pd

# %%
dict_mv = {
        "time": ["2023-12-24"]
    }

# %%
from collections import Counter
Counter(MV_list)
# Out:
# Counter({'ALKALOID「Black Out See Saw」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 111\u202f632\xa0vues il y a 17 heures 2 minutes et 27\xa0secondes': 3,
#          'Trickstar「Romantic Xday!」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 361\u202f413\xa0vues il y a 10 jours 2 minutes et 38\xa0secondes': 3,
#          '2wink「トゥウィンクル空中戦」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 258\u202f946\xa0vues il y a 2 semaines 2 minutes et 19\xa0secondes': 3,
#          '紅月「金色千夜夢舞台」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 272\u202f740\xa0vues il y a 3 semaines 2 minutes et 38\xa0secondes': 3,
#          'デッドマンズ「ROCK ROAR」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 115\u202f024\xa0vues il y a 1 mois 2 minutes et 31\xa0secondes': 3,
#          'UNDEAD「Resurrection of Soul」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 657\u202f774\xa0vues il y a 1 mois 2 minutes et 40\xa0secondes': 3,
# ...

# %%
print(len(set(MV_list)))

with open("../Desktop/Projects/about_a_certain_starvation_game/mv_youtube_viewed_{}.csv".format(str(now).split()[0]), "w") as o:
    for mv in set(MV_list):
        #print(mv)
        mv = mv.replace("あんさんぶるスターズ！！ Music ゲームサイズMV de Happy Elements株式会社 ", "$")
        mv = mv.replace("あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル ", "$")
        mv = mv.replace("vues il y a ", "$")
        mv = mv.replace("「", "$")
        mv = mv.replace("」", "")
        mv = re.sub(r' (\d minutes?)', r'$\g<1>', mv)
        print("\t".join(mv.split("$")))
        o.write("\t".join(mv.split("$")) + "\n")
        
        title = mv.split("$")[1]
        viewed = mv.split("$")[2].replace(" ", "").replace(" ", "")
        """
        exist = dict_mv.get(title, 0)
        if exist == viewed:
            dict_mv[title] = [int(viewed)]
        else:
            dict_mv[title] = [int(exist[0]) + int(viewed)]
        """
        dict_mv[title] = [int(viewed)]
# Out:
# 257
# Crazy:B	RISKY VENUS	3 044 579 	1 an	2 minutes
# UNDEAD	DESTRUCTION ROAD 	1 697 214 	2 ans	2 minutes et 15 secondes
# Crazy:B	Crazy Anthem	1 000 103 	6 mois	2 minutes et 38 secondes
# Valkyrie	今宵月の館にて 	3 293 902 	3 ans	2 minutes et 16 secondes
# UNDEAD	IMMORAL WORLD 	1 835 451 	2 ans	1 minute et 50 secondes
# Ra*bits	メルティ♡キッチン 	3 550 953 	3 ans	2 minutes et 17 secondes
# Valkyrie	Mémoire Antique 	1 848 296 	3 ans	2 minutes et 7 secondes
# デッドマンズ	ROCK ROAR 	115 024 	1 mois	2 minutes et 31 secondes
# Crazy:B	PARANOIA STREET 	5 743 182 	2 ans	2 minutes et 22 secondes
# ナイトキラーズ	Crush of Judgment 	1 045 968 	4 mois	2 minutes et 16 secondes
# Ra*bits	Milky Starry Charm 	2 181 830 	2 ans	2 minutes et 22 secondes
# 旧fine	Genuine Revelation	746 339 	8 mois	2 minutes et 6 secondes
# Eden	Awakening Myth	3 329 730 	1 an	2 minutes et 20 secondes
# ALKALOID	Distorted Heart 	7 085 705 	2 ans	2 minutes et 19 secondes
# 紅月	紅月いろは唄 	2 079 454 	2 ans	2 minutes
# ...

# %%
print(len(dict_mv))
# Out:
# 186

# %%
set(MV_list).difference(set(dict_mv.keys()))
# Out:
# {'2wink「Fighting Dreamer」 あんさんぶるスターズ！！ Music ゲームサイズMV de Happy Elements株式会社 1\u202f696\u202f852\xa0vues il y a 2 ans 2 minutes et 23\xa0secondes',
#  '2wink「Fighting Dreamer」 あんさんぶるスターズ！！ Music ゲームサイズMV de Happy Elements株式会社 1\u202f696\u202f853\xa0vues il y a 2 ans 2 minutes et 23\xa0secondes',
#  '2wink「Love×me⇄monsteR」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 595\u202f906\xa0vues il y a 2 mois 2 minutes et 26\xa0secondes',
#  '2wink「Mischievous Party Time!!」 あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 988\u202f511\xa0vues il y a 2 ans 2 minutes et 23\xa0secondes',
#  '2wink「Play "Tag"」 あんさんぶるスターズ！！ Music ゲームサイズMV de Happy Elements株式会社 1\u202f261\u202f975\xa0vues il y a 3 ans 2 minutes et 15\xa0secondes',
#  '2wink「Swee2wink Love Letter」あんさんぶるスターズ！！ Music ゲームサイズMV de あんスタチャンネル 2\u202f332\u202f927\xa0vues il y a 1 an 2 minutes et 27\xa0secondes',
# ...

# %%
df = pd.DataFrame(dict_mv).set_index("time")

# %%
df
# Out:
#             RISKY VENUS  DESTRUCTION ROAD   Crazy Anthem  今宵月の館にて   \
# time
# 2023-12-24      3044579            1697220       1000092   3293905
#
#             IMMORAL WORLD   メルティ♡キッチン   Mémoire Antique   ROCK ROAR   \
# time
# 2023-12-24         1835451     3550942           1848295      115027
#
#             PARANOIA STREET   Crush of Judgment   ...  1st SING-ALONG☆   \
# time                                              ...
# 2023-12-24           5743208             1045950  ...           1290708
#
#             Be The Party Bee!   Rebellion Star   Heart aid Cafeteria  \
# time
# 2023-12-24             5680706          2547293              1712889
#
#             Brilliant Smile   U.S.A.  歓迎☆トゥ・ウィンク雑技団   ハレノヒSugar Wave   \
# time
# 2023-12-24          3558531  6935159         2517325          1430596
#
#             ハニーミルクはお好みで   Artistic Partisan
# time
# 2023-12-24       1656116             5098285
#
# [1 rows x 185 columns]

# %%
print(len(df.columns.tolist()))
print(len(set(df.columns.tolist())))
print(df.columns.values)
# Out:
# 185
# 185
# ['RISKY VENUS' 'DESTRUCTION ROAD ' 'Crazy Anthem' '今宵月の館にて '
#  'IMMORAL WORLD ' 'メルティ♡キッチン ' 'Mémoire Antique ' 'ROCK ROAR '
#  'PARANOIA STREET ' 'Crush of Judgment ' 'Milky Starry Charm '
#  'Genuine Revelation' 'Awakening Myth' 'Distorted Heart ' '紅月いろは唄 '
#  'Romancing Cruise ' '野うさぎマーチ♪ ' 'Sunlit Smile! ' 'デートプランA to Z '
#  'トゥウィンクル空中戦 ' 'The Beast of the End ' '凱旋歌 ' 'BIGBANG REFLECTION!! '
#  'エメラルドプラネット ' 'アンリミテッド☆パワー!!!!! ' 'Le temps des fleurs' '翼モラトリアム '
#  '終わらないシンフォニア ' 'UNDYING HOLY LOVE ' '辻風に吹かれて' 'Swee2wink Love Letter'
#  'Mystic Fragrance ' 'FIST OF SOUL' 'Turbulent Storm ' '金色千夜夢舞台 ' 'ネビュラ '
#  'Acanthe' 'Finder Girl ' 'The Tempest Night ' '恋はプリマヴェーラ！ '
#  'SUPER NOVA REVOLU5TAR ' 'Little Romance ' 'BREAKTHROUGH! '
#  'Feathers of Ark ' 'Honeycomb Summer ' 'No name yet' 'Sustain Memories'
#  '楽園追放 -Faith Conquest- ' '祝福のLibrary ' 'Love it Love it ' '薄紅色の約束 '
#  'CHERRY HAPPY STREAM' '熱血☆流星忍法帖 ' 'パラレルメイズ ' 'Tell Your World'
# ...

# %%
file_name = "../Desktop/Projects/about_a_certain_starvation_game/mv_youtube_viewed_stats.csv"
df.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
with open("../Desktop/Projects/about_a_certain_starvation_game/mv_youtube_viewed_stats.csv", "w") as o:

# %%
import sqlite3
conn = sqlite3.connect('ES_MV_YouTube.db')

# %%
c = conn.cursor()

# %%
c.execute('''CREATE TABLE IF NOT EXISTS mv_youtube(
    id INTEGER PRIMARY KEY,
    name TEXT,
    viewed  INTEGER,
    releaseddate
);''')

# %% [markdown]
# # ❎

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
"""import urllib
response = urllib.request.urlopen(Channel_videos)
soup = BeautifulSoup(response, "html.parser")"""

# %%
print(soup)
# Out:
# <html dir="ltr" lang="fr"><head><base href="https://consent.youtube.com/"/><meta content="origin" name="referrer"/><script nonce="">window['ppConfig'] = {productName: 'ConsentUi', deleteIsEnforced:  true , sealIsEnforced: false, heartbeatRate:  0.5 , periodicReportingRateMillis:  60000.0 , disableAllReporting:  false };(function(){'use strict';function k(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}}var l="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a};
# ...

# %%
#videoList = soup.find_all("a", {"id": "video-title-link"})
#videoList = soup.find_all("a", {"class": "yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media"})
videoList = soup.findAll('a')
print(videoList)
# Out:
# [<a href="https://policies.google.com/technologies/cookies?hl=fr&amp;utm_source=ucb" target="_blank">cookies</a>]
